# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from subprocess import check_output
print(check_output(["ls"]).decode("utf8"))
# Out:
# TrainingData.xlsx
# Untitled.ipynb
# sample_submission.csv
# train_2017.csv
# zillow_data_dictionary.xlsx
# ~$TrainingData.xlsx
# ~$zillow_data_dictionary.xlsx

# %%
target = pd.read_csv("train_2017.csv")
print(target.shape)
target.head()
# Out:
# (77613, 3)
#    parcelid  logerror transactiondate
# 0  14297519  0.025595      2017-01-01
# 1  17052889  0.055619      2017-01-01
# 2  14186244  0.005383      2017-01-01
# 3  12177905 -0.103410      2017-01-01
# 4  10887214  0.006940      2017-01-01

# %%
properties = pd.read_excel("TrainingData.xlsx")
print(properties.shape)
properties.head()
# Out:
# (4999, 58)
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0           0                  NaN                    NaN
# 1          0.0           0                  NaN                    NaN
# 2          0.0           0                  5.0                    NaN
# 3          0.0           0                  3.0                    6.0
# 4          0.0           0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# 0                NaN         NaN         ...                       NaN
# 1                NaN         NaN         ...                       NaN
# 2                NaN         NaN         ...                       1.0
# 3                NaN         NaN         ...                       1.0
# 4                NaN         NaN         ...                       1.0
#
#    fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0            NaN                         NaN                9.0
# 1            NaN                         NaN            27516.0
# 2            NaN                    660680.0          1434941.0
# 3            NaN                    580059.0          1174475.0
# 4            NaN                    196751.0           440101.0
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0            2016                    9.0        NaN                 NaN
# 1            2015                27516.0        NaN                 NaN
# 2            2016               774261.0   20800.37                 NaN
# 3            2016               594416.0   14557.57                 NaN
# 4            2016               243350.0    5725.17                 NaN
#
#    taxdelinquencyyear  censustractandblock
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 58 columns]

# %%
plt.figure(figsiez=(8,6))
plt.scatter(range())
